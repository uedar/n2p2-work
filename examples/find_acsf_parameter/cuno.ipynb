# %% [markdown]
# #### using this code
# https://github.com/flobuch/n2p2/blob/symfunc_paramgen/tools/python/symfunc_paramgen/src/sfparamgen.py

# %%
import sys
sys.path.append('/home/ueda/Project_GP_Cu+CO/hyps/n2p2/tools/python')

# %%
from sfparamgen import SymFuncParamGenerator

# %%
myGenerator = SymFuncParamGenerator(elements=['Cu', 'N', 'O'], r_cutoff = 10.)

# %%
myGenerator.symfunc_type = 'radial'
myGenerator.generate_radial_params(rule='imbalzano2018', mode='shift', nb_param_pairs=5)
myGenerator.write_settings_overview()
myGenerator.write_parameter_strings()
# Out:
# #########################################################################
# # Radial symmetry function set, for elements ['Cu', 'N', 'O']
# #########################################################################
# # r_cutoff       = 10.0
# # The following settings were used for generating sets
# # of values for the radial parameters r_shift and eta:
# # rule           = imbalzano2018
# # mode           = shift
# # nb_param_pairs = 5
# # Sets of values for parameters:
# # r_shift_grid   = [2.     2.7595 3.8073 5.2531 7.2478]
# # eta_grid       = [1.7338 0.9108 0.4784 0.2513 0.132 ]
#
# symfunction_short Cu 2 Cu 1.734E+00 2.000E+00 1.000E+01
# symfunction_short Cu 2 Cu 9.108E-01 2.759E+00 1.000E+01
# symfunction_short Cu 2 Cu 4.784E-01 3.807E+00 1.000E+01
# symfunction_short Cu 2 Cu 2.513E-01 5.253E+00 1.000E+01
# symfunction_short Cu 2 Cu 1.320E-01 7.248E+00 1.000E+01
#
# symfunction_short Cu 2 N  1.734E+00 2.000E+00 1.000E+01
# symfunction_short Cu 2 N  9.108E-01 2.759E+00 1.000E+01
# symfunction_short Cu 2 N  4.784E-01 3.807E+00 1.000E+01
# symfunction_short Cu 2 N  2.513E-01 5.253E+00 1.000E+01
# symfunction_short Cu 2 N  1.320E-01 7.248E+00 1.000E+01
#
# symfunction_short Cu 2 O  1.734E+00 2.000E+00 1.000E+01
# symfunction_short Cu 2 O  9.108E-01 2.759E+00 1.000E+01
# symfunction_short Cu 2 O  4.784E-01 3.807E+00 1.000E+01
# symfunction_short Cu 2 O  2.513E-01 5.253E+00 1.000E+01
# symfunction_short Cu 2 O  1.320E-01 7.248E+00 1.000E+01
#
# symfunction_short N  2 Cu 1.734E+00 2.000E+00 1.000E+01
# symfunction_short N  2 Cu 9.108E-01 2.759E+00 1.000E+01
# symfunction_short N  2 Cu 4.784E-01 3.807E+00 1.000E+01
# symfunction_short N  2 Cu 2.513E-01 5.253E+00 1.000E+01
# symfunction_short N  2 Cu 1.320E-01 7.248E+00 1.000E+01
#
# symfunction_short N  2 N  1.734E+00 2.000E+00 1.000E+01
# symfunction_short N  2 N  9.108E-01 2.759E+00 1.000E+01
# symfunction_short N  2 N  4.784E-01 3.807E+00 1.000E+01
# symfunction_short N  2 N  2.513E-01 5.253E+00 1.000E+01
# symfunction_short N  2 N  1.320E-01 7.248E+00 1.000E+01
#
# symfunction_short N  2 O  1.734E+00 2.000E+00 1.000E+01
# symfunction_short N  2 O  9.108E-01 2.759E+00 1.000E+01
# symfunction_short N  2 O  4.784E-01 3.807E+00 1.000E+01
# symfunction_short N  2 O  2.513E-01 5.253E+00 1.000E+01
# symfunction_short N  2 O  1.320E-01 7.248E+00 1.000E+01
#
# symfunction_short O  2 Cu 1.734E+00 2.000E+00 1.000E+01
# symfunction_short O  2 Cu 9.108E-01 2.759E+00 1.000E+01
# symfunction_short O  2 Cu 4.784E-01 3.807E+00 1.000E+01
# symfunction_short O  2 Cu 2.513E-01 5.253E+00 1.000E+01
# symfunction_short O  2 Cu 1.320E-01 7.248E+00 1.000E+01
#
# symfunction_short O  2 N  1.734E+00 2.000E+00 1.000E+01
# symfunction_short O  2 N  9.108E-01 2.759E+00 1.000E+01
# symfunction_short O  2 N  4.784E-01 3.807E+00 1.000E+01
# symfunction_short O  2 N  2.513E-01 5.253E+00 1.000E+01
# symfunction_short O  2 N  1.320E-01 7.248E+00 1.000E+01
#
# symfunction_short O  2 O  1.734E+00 2.000E+00 1.000E+01
# symfunction_short O  2 O  9.108E-01 2.759E+00 1.000E+01
# symfunction_short O  2 O  4.784E-01 3.807E+00 1.000E+01
# symfunction_short O  2 O  2.513E-01 5.253E+00 1.000E+01
# symfunction_short O  2 O  1.320E-01 7.248E+00 1.000E+01

# %%
myGenerator.symfunc_type = 'angular_narrow'
myGenerator.zetas = [1.0, 6.0]
myGenerator.generate_radial_params(rule='gastegger2018', mode='center', nb_param_pairs=2, r_lower=1.5)
myGenerator.write_settings_overview()
myGenerator.write_parameter_strings()
# Out:
# #########################################################################
# # Narrow angular symmetry function set, for elements ['Cu', 'N', 'O']
# #########################################################################
# # r_cutoff       = 10.0
# # The following settings were used for generating sets
# # of values for the radial parameters r_shift and eta:
# # rule           = gastegger2018
# # mode           = center
# # nb_param_pairs = 2
# # r_lower        = 1.5
# # r_upper        = 10.0
# # Sets of values for parameters:
# # r_shift_grid   = [0. 0.]
# # eta_grid       = [0.2222 0.005 ]
# # lambdas        = [-1.  1.]
# # zetas          = [1. 6.]
#
# symfunction_short Cu 3 Cu Cu 2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu Cu 2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu Cu 2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu Cu 2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu Cu 5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu Cu 5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu Cu 5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu Cu 5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short Cu 3 Cu N  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu N  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu N  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu N  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu N  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu N  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu N  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu N  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short Cu 3 Cu O  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu O  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu O  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu O  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu O  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu O  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu O  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 Cu O  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short Cu 3 N  N  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 N  N  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 N  N  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 N  N  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 N  N  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 N  N  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 N  N  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 N  N  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short Cu 3 N  O  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 N  O  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 N  O  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 N  O  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 N  O  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 N  O  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 N  O  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 N  O  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short Cu 3 O  O  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 O  O  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 O  O  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 O  O  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 O  O  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 O  O  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 O  O  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short Cu 3 O  O  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short N  3 Cu Cu 2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu Cu 2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu Cu 2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu Cu 2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu Cu 5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu Cu 5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu Cu 5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu Cu 5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short N  3 Cu N  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu N  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu N  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu N  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu N  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu N  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu N  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu N  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short N  3 Cu O  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu O  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu O  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu O  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu O  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu O  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu O  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 Cu O  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short N  3 N  N  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 N  N  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 N  N  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 N  N  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 N  N  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 N  N  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 N  N  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 N  N  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short N  3 N  O  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 N  O  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 N  O  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 N  O  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 N  O  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 N  O  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 N  O  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 N  O  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short N  3 O  O  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 O  O  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 O  O  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 O  O  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 O  O  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 O  O  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 O  O  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short N  3 O  O  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short O  3 Cu Cu 2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu Cu 2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu Cu 2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu Cu 2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu Cu 5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu Cu 5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu Cu 5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu Cu 5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short O  3 Cu N  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu N  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu N  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu N  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu N  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu N  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu N  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu N  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short O  3 Cu O  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu O  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu O  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu O  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu O  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu O  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu O  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 Cu O  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short O  3 N  N  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 N  N  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 N  N  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 N  N  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 N  N  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 N  N  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 N  N  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 N  N  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short O  3 N  O  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 N  O  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 N  O  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 N  O  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 N  O  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 N  O  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 N  O  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 N  O  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00
#
# symfunction_short O  3 O  O  2.222E-01 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 O  O  2.222E-01  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 O  O  2.222E-01 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 O  O  2.222E-01  1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 O  O  5.000E-03 -1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 O  O  5.000E-03  1 1.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 O  O  5.000E-03 -1 6.000E+00 1.000E+01 0.000E+00
# symfunction_short O  3 O  O  5.000E-03  1 6.000E+00 1.000E+01 0.000E+00

# %%
myGenerator.symfunc_type = 'angular_wide'
myGenerator.generate_radial_params(rule='gastegger2018', mode='center', nb_param_pairs=3, r_lower=1.5)
myGenerator.write_settings_overview()
myGenerator.write_parameter_strings()
# Out:
# #########################################################################
# # Wide angular symmetry function set, for elements ['Cu']
# #########################################################################
# # r_cutoff       = 6.0
# # The following settings were used for generating sets
# # of values for the radial parameters r_shift and eta:
# # rule           = gastegger2018
# # mode           = center
# # nb_param_pairs = 3
# # r_lower        = 1.5
# # r_upper        = 6.0
# # Sets of values for parameters:
# # r_shift_grid   = [0. 0. 0.]
# # eta_grid       = [0.2222 0.0356 0.0139]
# # lambdas        = [-1.  1.]
# # zetas          = [1. 6.]
#
# symfunction_short Cu 9 Cu Cu 2.222E-01 -1 1.000E+00 6.000E+00 0.000E+00
# symfunction_short Cu 9 Cu Cu 2.222E-01  1 1.000E+00 6.000E+00 0.000E+00
# symfunction_short Cu 9 Cu Cu 2.222E-01 -1 6.000E+00 6.000E+00 0.000E+00
# symfunction_short Cu 9 Cu Cu 2.222E-01  1 6.000E+00 6.000E+00 0.000E+00
# symfunction_short Cu 9 Cu Cu 3.556E-02 -1 1.000E+00 6.000E+00 0.000E+00
# symfunction_short Cu 9 Cu Cu 3.556E-02  1 1.000E+00 6.000E+00 0.000E+00
# symfunction_short Cu 9 Cu Cu 3.556E-02 -1 6.000E+00 6.000E+00 0.000E+00
# symfunction_short Cu 9 Cu Cu 3.556E-02  1 6.000E+00 6.000E+00 0.000E+00
# symfunction_short Cu 9 Cu Cu 1.389E-02 -1 1.000E+00 6.000E+00 0.000E+00
# symfunction_short Cu 9 Cu Cu 1.389E-02  1 1.000E+00 6.000E+00 0.000E+00
# symfunction_short Cu 9 Cu Cu 1.389E-02 -1 6.000E+00 6.000E+00 0.000E+00
# symfunction_short Cu 9 Cu Cu 1.389E-02  1 6.000E+00 6.000E+00 0.000E+00
